# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.6.0+cu124
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, fastai, peft, sentence-transformers, timm, torchaudio, torchdata, torchvision

# %%
dataset = load_dataset("SetFit/sst2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-2350957029.py in <cell line: 0>()
# ----> 1 dataset = load_dataset("SetFit/sst2")
#
# NameError: name 'load_dataset' is not defined

# %%
# !pip install transformers==4.45.2  datasets evaluate accelerate bitsandbytes  scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 366.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 879.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.6 MB/s eta 0:00:00
# ...

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.45.2
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: peft, sentence-transformers

# %%
# !pip install transformers==4.35.2

# %%
import torch
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    BitsAndBytesConfig,
    TrainingArguments,
    Trainer,
    DataCollatorWithPadding,
    default_data_collator,
)
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# %%
# !pip install  datasets==2.18.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 10.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.2.0 which is incompatible.
# ...

# %%
# !pip show datasets
# Out:
# Name: datasets
# Version: 2.14.4
# Summary: HuggingFace community-driven open-source library of datasets
# Home-page: https://github.com/huggingface/datasets
# Author: HuggingFace Inc.
# Author-email: thomas@huggingface.co
# License: Apache 2.0
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: aiohttp, dill, fsspec, huggingface-hub, multiprocess, numpy, packaging, pandas, pyarrow, pyyaml, requests, tqdm, xxhash
# Required-by: evaluate, torchtune

# %%
# 1. 加载英文情感二分类数据集 IMDb
# dataset = load_dataset("imdb")
# 1. 加载英文情感二分类数据集 SST-2（GLUE子集）
# dataset = load_dataset("glue", "sst2")
data = [
    {"sentence": "This movie was absolutely terrible.", "label": 0},
    {"sentence": "I loved every moment of this wonderful film!", "label": 1},
    {"sentence": "The acting was painfully bad.", "label": 0},
    {"sentence": "A heartwarming story that made me smile.", "label": 1},
    {"sentence": "Worst dining experience I've ever had.", "label": 0},
    {"sentence": "The sunset view took my breath away.", "label": 1},
    {"sentence": "Customer service was rude and unhelpful.", "label": 0},
    {"sentence": "My new puppy brings me so much joy.", "label": 1},
    {"sentence": "The product broke after just one day.", "label": 0},
    {"sentence": "This book changed my perspective on life.", "label": 1},
    {"sentence": "Traffic was unbearable this morning.", "label": 0},
    {"sentence": "Grandma's cookies are the best in the world.", "label": 1},
    {"sentence": "The hotel room was dirty and smelled bad.", "label": 0},
    {"sentence": "Winning the championship felt incredible.", "label": 1},
    {"sentence": "This software keeps crashing every hour.", "label": 0},
    {"sentence": "My wedding day was perfect in every way.", "label": 1},
    {"sentence": "The concert was canceled last minute.", "label": 0},
    {"sentence": "Freshly baked bread smells amazing.", "label": 1},
    {"sentence": "Flight delayed for 8 hours with no explanation.", "label": 0},
    {"sentence": "Seeing my baby's first steps was magical.", "label": 1},
    {"sentence": "The soup was cold and tasteless.", "label": 0},
    {"sentence": "My team worked together brilliantly.", "label": 1},
    {"sentence": "Package arrived damaged and incomplete.", "label": 0},
    {"sentence": "Morning coffee makes me feel alive.", "label": 1},
    {"sentence": "The tour guide was boring and uninformed.", "label": 0},
    {"sentence": "Spring flowers blooming is so beautiful.", "label": 1},
    {"sentence": "Internet connection keeps dropping out.", "label": 0},
    {"sentence": "Surprise party organized by friends was touching.", "label": 1},
    {"sentence": "The shoes gave me blisters immediately.", "label": 0},
    {"sentence": "Warm hug from a loved one feels comforting.", "label": 1},
    {"sentence": "Doctor's appointment was rushed and impersonal.", "label": 0},
    {"sentence": "First snow of the year is always exciting.", "label": 1},
    {"sentence": "Neighbors are loud and disrespectful.", "label": 0},
    {"sentence": "Achieving my fitness goal was rewarding.", "label": 1},
    {"sentence": "Phone battery dies too quickly.", "label": 0},
    {"sentence": "Family reunion filled me with happiness.", "label": 1},
    {"sentence": "Tax paperwork is confusing and frustrating.", "label": 0},
    {"sentence": "Puppies playing together is adorable.", "label": 1},
    {"sentence": "The play was dull and poorly acted.", "label": 0},
    {"sentence": "Beach vacation relaxed me completely.", "label": 1},
    {"sentence": "Meal was overcooked and overpriced.", "label": 0},
    {"sentence": "Seeing my artwork displayed was thrilling.", "label": 1},
    {"sentence": "Car broke down on the highway.", "label": 0},
    {"sentence": "Baby's laughter is contagious.", "label": 1},
    {"sentence": "Plumbing issues flooded the bathroom.", "label": 0},
    {"sentence": "Promotion at work made me proud.", "label": 1},
    {"sentence": "Movie plot made no sense whatsoever.", "label": 0},
    {"sentence": "Gardening helps me feel peaceful.", "label": 1},
    {"sentence": "Delivery never arrived as promised.", "label": 0},
    {"sentence": "Old friends reunited after years apart.", "label": 1},
    {"sentence": "Air conditioning stopped working in summer.", "label": 0},
    {"sentence": "Homemade pie tasted like childhood.", "label": 1},
    {"sentence": "New shoes gave me terrible blisters.", "label": 0},
    {"sentence": "Volunteering at the shelter was fulfilling.", "label": 1},
    {"sentence": "Restaurant messed up our reservation.", "label": 0},
    {"sentence": "Seeing the Grand Canyon was awe-inspiring.", "label": 1},
    {"sentence": "Computer crashed and lost all my files.", "label": 0},
    {"sentence": "Hearing my favorite song cheered me up.", "label": 1},
    {"sentence": "Hotel overcharged my credit card.", "label": 0},
    {"sentence": "Finishing the marathon was empowering.", "label": 1},
    {"sentence": "Taxi driver took the longest route.", "label": 0},
    {"sentence": "Christmas morning with family is special.", "label": 1},
    {"sentence": "New phone has terrible battery life.", "label": 0},
    {"sentence": "Seeing dolphins in the wild was amazing.", "label": 1},
    {"sentence": "Mechanic overcharged for simple repair.", "label": 0},
    {"sentence": "Graduation day was unforgettable.", "label": 1},
    {"sentence": "Mosquito bites kept me awake all night.", "label": 0},
    {"sentence": "First date went better than expected.", "label": 1},
    {"sentence": "Flight was turbulent and frightening.", "label": 0},
    {"sentence": "Surprise gift from partner was thoughtful.", "label": 1},
    {"sentence": "New jeans ripped after one wash.", "label": 0},
    {"sentence": "Sunrise over the mountains was breathtaking.", "label": 1},
    {"sentence": "Customer support never answered my call.", "label": 0},
    {"sentence": "Adopting my rescue dog was life-changing.", "label": 1},
    {"sentence": "Neighbor's dog barks all night.", "label": 0},
    {"sentence": "Freshly painted room looks fantastic.", "label": 1},
    {"sentence": "Important email went to spam folder.", "label": 0},
    {"sentence": "Weekend getaway was exactly what I needed.", "label": 1},
    {"sentence": "New recipe turned out disastrous.", "label": 0},
    {"sentence": "Seeing my child graduate filled me with pride.", "label": 1},
    {"sentence": "Parking ticket ruined my morning.", "label": 0},
    {"sentence": "Fireplace makes the room cozy.", "label": 1},
    {"sentence": "Important package was left in the rain.", "label": 0},
    {"sentence": "Morning walk clears my mind.", "label": 1},
    {"sentence": "Haircut turned out awful.", "label": 0},
    {"sentence": "Reconnecting with old friends was wonderful.", "label": 1},
    {"sentence": "New sofa arrived with stains.", "label": 0},
    {"sentence": "Baby's first word was magical.", "label": 1},
    {"sentence": "Airline lost my luggage.", "label": 0},
    {"sentence": "Summer breeze feels refreshing.", "label": 1},
    {"sentence": "New headphones stopped working.", "label": 0},
    {"sentence": "Proposal was romantic and perfect.", "label": 1},
    {"sentence": "Coffee spilled on my new shirt.", "label": 0},
    {"sentence": "Rainbow after the storm was beautiful.", "label": 1},
    {"sentence": "Movie ending was disappointing.", "label": 0},
    {"sentence": "Surprise visit from best friend made my day.", "label": 1},
    {"sentence": "New restaurant had terrible service.", "label": 0},
    {"sentence": "Hiking to the waterfall was exhilarating.", "label": 1},
    {"sentence": "Ice cream melted before I could eat it.", "label": 0},
    {"sentence": "Seeing my parents happy warms my heart.", "label": 1},
    {"sentence": "New phone app is glitchy.", "label": 0},
    {"sentence": "Finding money in old jeans was lucky.", "label": 1},
    {"sentence": "Boss criticized my work unfairly.", "label": 0},
    {"sentence": "Hot chocolate on a cold day is perfect.", "label": 1},
    {"sentence": "New shoes are uncomfortable.", "label": 0},
    {"sentence": "Seeing my garden bloom is satisfying.", "label": 1}
]

# %%
import datasets
from datasets import Dataset,DatasetDict
# import pandas as pd
# # 转换为pandas DataFrame
# df = pd.DataFrame(data)

# # 转换为Hugging Face Dataset
# dataset = Dataset.from_pandas(df)
# dataset

# 直接构建Dataset（不使用pandas）
dataset = Dataset.from_dict({
    "text": [d["sentence"] for d in data],  # 将"sentence"字段改为"text"
    "label": [d["label"] for d in data]
})

# 创建train/test split (80% train, 20% test)
split_dataset = dataset.train_test_split(test_size=0.2, seed=42)

# 转换为DatasetDict格式（包含train/test）
dataset_dict = DatasetDict({
    "train": split_dataset["train"],
    "test": split_dataset["test"]

})

print(dataset_dict)
dataset = dataset_dict
# # 添加特征描述（明确text和label类型）
# features = {
#     "text": datasets.Value("string"),
#     "label": datasets.ClassLabel(names=["negative", "positive"]),
# }

# dataset_dict = dataset_dict.cast(features)

# # 查看结果
# print(dataset_dict)
# print("\nTrain set first example:")
# print(dataset_dict["train"][0])
# print("\nTest set size:", len(dataset_dict["test"]))
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 84
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 22
#     })
# })

# %%
# 2. 加载分词器
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
# 3. 数据预处理函数
def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True, padding="max_length", max_length=256)

encoded_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# ...
# Map:   0%|          | 0/22 [00:00<?, ? examples/s]

# %%
# 4. BitsAndBytesConfig 量化配置（4bit 或 8bit）
# quantization_config = BitsAndBytesConfig(
#     load_in_4bit=True,                   # 4bit量化，改为 False 并 load_in_8bit=True 可切换8bit
#     bnb_4bit_quant_type="nf4",           # nf4量化类型，4bit推荐
#     bnb_4bit_use_double_quant=True,      # 双重量化，节省显存
#     bnb_4bit_compute_dtype=torch.bfloat16  # 计算时使用bfloat16加速
#     # llm_int8_skip_modules=["classifier"]  # 如需跳过分类层量化，可取消注释
# )

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,                   # 4bit量化，改为 False 并 load_in_8bit=True 可切换8bit
    bnb_4bit_quant_type="nf4",           # nf4量化类型，4bit推荐
    bnb_4bit_use_double_quant=True,      # 双重量化，节省显存
    bnb_4bit_compute_dtype=torch.bfloat16  # 计算时使用bfloat16加速
)

# %%
# 5. 加载量化模型（全参数量化）
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2,
    quantization_config=quantization_config,
    # device_map="auto"  # 自动分配设备

)

# <<== 新增：配置LoRA参数
from peft import LoraConfig, get_peft_model
lora_config = LoraConfig(
    r=16,                              # LoRA秩，调节参数量
    lora_alpha=32,
    target_modules=["query", "key", "value"],  # 量化模型中注意力层常用模块名
    lora_dropout=0.1,
    bias="none",
    task_type="SEQ_CLS"
)
model = get_peft_model(model, lora_config)
# Out:
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 6. 准备训练参数
training_args = TrainingArguments(
    output_dir="./bert-4bit-imdb",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    num_train_epochs=10,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=50,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    greater_is_better=True,
    fp16=False,  # 量化训练不使用fp16
    report_to=[],  # <<== 关闭所有日志报告，包括wandb

)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# 7. 数据整理器，自动padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
# 8. 评估指标函数
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average="binary")
    acc = accuracy_score(labels, predictions)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

# %%
# 9. 初始化 Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encoded_dataset["train"],
    eval_dataset=encoded_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
# 10. 开始训练
trainer.train()
# Out:
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 00:37, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>nan</td>
#       <td>0.636364</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>nan</td>
#       <td>0.636364</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>nan</td>
#       <td>0.636364</td>
#       <td>0.000000</td>
# ...

# %%
# 11. 保存量化模型
trainer.save_model("./bert-4bit-imdb-quantized")

# %%
# !du -sh *
# Out:
# 23M	bert-4bit-imdb
# 4.4M	bert-4bit-imdb-quantized
# 12K	logs
# 55M	sample_data

# %%
import torch
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    BitsAndBytesConfig,
    TrainingArguments,
    Trainer,
    DataCollatorWithPadding,
    default_data_collator,
)
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from peft import LoraConfig, get_peft_model

# 1. 加载英文情感二分类数据集 IMDb
dataset = load_dataset("imdb")

# 2. 加载分词器
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# 3. 数据预处理函数
def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True, padding="max_length", max_length=256)

encoded_dataset = dataset.map(preprocess_function, batched=True)

# 4. BitsAndBytesConfig 量化配置（4bit 或 8bit）
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,                   # 4bit量化，改为 False 并 load_in_8bit=True 可切换8bit
    bnb_4bit_quant_type="nf4",           # nf4量化类型，4bit推荐
    bnb_4bit_use_double_quant=True,      # 双重量化，节省显存
    bnb_4bit_compute_dtype=torch.bfloat16  # 计算时使用bfloat16加速
    # llm_int8_skip_modules=["classifier"]  # 如需跳过分类层量化，可取消注释
)

# 5. 加载量化模型（全参数量化）
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2,
    quantization_config=quantization_config,
    device_map="auto"  # 自动分配设备
)
# <<== 新增：配置LoRA参数
lora_config = LoraConfig(
    r=16,                              # LoRA秩，调节参数量
    lora_alpha=32,
    target_modules=["query", "key", "value"],  # 量化模型中注意力层常用模块名
    lora_dropout=0.1,
    bias="none",
    task_type="SEQ_CLS"
)
model = get_peft_model(model, lora_config)

# 6. 准备训练参数
training_args = TrainingArguments(
    output_dir="./bert-4bit-imdb",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=50,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    greater_is_better=True,
    fp16=False,  # 量化训练不使用fp16
)

# 7. 数据整理器，自动padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# 8. 评估指标函数
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average="binary")
    acc = accuracy_score(labels, predictions)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

# 9. 初始化 Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encoded_dataset["train"],
    eval_dataset=encoded_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# 10. 开始训练
trainer.train()

# 11. 保存量化模型
trainer.save_model("./bert-4bit-imdb-quantized")

# 12. 合并LoRA适配器到基础模型并保存完整模型
merged_model = model.merge_and_unload()  # 合并LoRA权重到基础模型

# 保存合并后的模型
merged_model.save_pretrained("./bert-4bit-imdb-merged")
tokenizer.save_pretrained("./bert-4bit-imdb-merged")  # 同时保存分词器

print("模型已合并并保存到 bert-4bit-imdb-merged 目录")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-59-1667484214.py in <cell line: 0>()
#      15
#      16 # 1. 加载英文情感二分类数据集 IMDb
# ---> 17 dataset = load_dataset("imdb")
#      18
#      19 # 2. 加载分词器
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2110     trust_remote_code: Optional[bool] = None,
#    2111     _require_default_config_name=True,
# -> 2112     **config_kwargs,
#    2113 ) -> DatasetBuilder:
# ...
